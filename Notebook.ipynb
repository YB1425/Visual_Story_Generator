# %%
# !pip install gradio transformers torch Pillow gtts
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gradio in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (4.44.0)
# Requirement already satisfied: transformers in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (4.45.1)
# Requirement already satisfied: torch in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (2.4.1)
# Requirement already satisfied: Pillow in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (9.5.0)
# Requirement already satisfied: gtts in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (2.5.3)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (4.6.0)
# Requirement already satisfied: fastapi<1.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.115.0)
# Requirement already satisfied: ffmpy in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (6.4.5)
# Requirement already satisfied: jinja2<4.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: orjson~=3.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pydantic>=2.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (2.9.2)
# Requirement already satisfied: pydub in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.6.8)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio) (0.31.0)
# Requirement already satisfied: fsspec in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio-client==1.3.0->gradio) (2024.9.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: filelock in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: sympy in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: setuptools in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from gtts) (8.1.7)
# Requirement already satisfied: idna>=2.8 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: colorama in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from fastapi<1.0->gradio) (0.38.6)
# Requirement already satisfied: certifi in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from matplotlib~=3.0->gradio) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.8.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\yasser\iclouddrive\documents\misc\programming projects\tuwaiq ds and ml bootcamp\story generation from photo\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import gradio as gr
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration, pipeline
import random
from gtts import gTTS
import re

# Load the BLIP model for generating captions
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")


# Load GPT-2 model for story generation
story_generator = pipeline("text-generation", model="gpt2")

# Load translation model (English to Arabic)
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-en-ar")

# Default characters and settings
default_characters = [
    "Ali", "Fatima", "Omar", "Amina", "Zaid", "Layla", "Hassan", "Sara",
    "Yusuf", "Noura", "Khalid", "Rania", "Amir", "Jasmine", "Farah", "Sami",
    "Aisha", "Rami", "Zayn", "Dalia", "Bilal", "Ibtisam", "Mansour", "Afnan",
    "Jamal", "Asma", "Khadija", "Hadi", "Maya", "Samir", "Nabil", "Lina",
    "Tariq", "Yara", "Munir", "Ranya", "Firas", "Nadia", "Alaa", "Nida",
    "Omar", "Dina", "Zein", "Rami", "Yasmin", "Salma", "Jamil", "Khaled"
]

default_settings = [
    "a mystical forest", "a bustling city", "an ancient castle", "a snowy mountain village",
    "a sunny beach", "a dark cave", "a magical kingdom", "a quiet library",
    "a colorful carnival", "a haunted house", "a space station", "a serene garden",
    "a busy marketplace", "a futuristic city", "a pirate ship", "a wild savannah",
    "a snowy tundra", "a tropical island", "an underwater city", "a hidden valley",
    "a dragon's lair", "an enchanted meadow", "a witch's cottage", "a cozy cabin",
    "a bustling train station", "a giant's castle", "a fairy-tale village",
    "a mysterious island", "a historical battlefield", "an abandoned factory",
    "a magical forest glen", "a secret garden", "a royal palace", "a shimmering lagoon",
    "a giant treehouse", "a whimsical tree-lined street", "a rugged mountain range",
    "a starry night sky", "a bright sunny day", "a lively zoo", "an exciting amusement park"
]


def preprocess_image(image):
    return image.convert("RGB").resize((256, 256))


def get_captions(images):
    captions = []
    for img in images:
        processed_img = preprocess_image(img)
        inputs = blip_processor(images=processed_img, return_tensors="pt")
        caption = blip_model.generate(**inputs)
        caption_text = blip_processor.decode(caption[0], skip_special_tokens=True)
        captions.append(caption_text)
    return " ".join(captions)


def clean_up_caption(caption):
    caption = caption.strip().capitalize()
    scene_descriptions = ["scene", "view", "image", "photo", "picture"]
    for word in scene_descriptions:
        caption = caption.replace(word, "").strip()

    # Simplifying specific terms
    caption = caption.replace("a snowy scene", "on a snowy mountain").replace("log cabin", "log cabin").strip()

    return caption


def generate_relevant_setting(captions):
    keywords_to_settings = {
        "castle": "an ancient castle",
        "forest": "a mystical forest",
        "mountain": "a snowy mountain village",
        "beach": "a sunny beach"
    }

    for keyword, setting in keywords_to_settings.items():
        if keyword in captions.lower():
            return setting
    return "a mysterious place"


def integrate_caption_into_story(caption, character, setting):
    cleaned_caption = clean_up_caption(caption)

    # Lists for interaction scenarios
    animals = ["cat", "dog", "bear", "lion", "eagle", "bird", "rabbit", "tiger", "elephant", "fish", "horse", "wolf",
               "deer"]
    beings = ["girl", "boy", "man", "woman", "child", "hero", "princess", "prince", "wizard", "witch", "monster",
              "creature"]
    items = ["book", "sword", "fruit", "food", "technology", "map", "key", "potion", "gem", "tool", "lantern", "shield"]

    if "cabin" in cleaned_caption and "snow" in cleaned_caption:
        return f"In a cozy log cabin on a snowy mountain, there lived a brave character named {character}."
    elif "mountain" in cleaned_caption:
        return f"High up in the mountains, {character} embarked on an adventure."
    elif any(animal in cleaned_caption for animal in animals):
        return f"One day, {character} encountered a {cleaned_caption} that changed everything."
    elif any(being in cleaned_caption for being in beings):
        return f"A {cleaned_caption} approached {character} with a sense of wonder."
    elif "treasure" in cleaned_caption:
        return f"{character} stumbled upon a treasure in the {cleaned_caption}, which held many secrets."
    elif any(item in cleaned_caption for item in items):
        return f"{character} picked up a {cleaned_caption}, which turned out to be very special."
    else:
        return f"{character} was surrounded by {cleaned_caption} during their adventure."


def trim_story(story, max_lines, max_words=None):
    # Split the story into sentences using regex to handle punctuation correctly
    sentences = re.split(r'(?<=[.!?]) +', story.strip())
    trimmed_lines = []
    line_count = 0
    word_count = 0

    for sentence in sentences:
        sentence_word_count = len(sentence.split())

        # If max_words is specified, check against it
        if max_words is not None and (word_count + sentence_word_count) > max_words:
            break

        # Check if adding this sentence would exceed max_lines
        if line_count < max_lines:
            trimmed_lines.append(sentence.strip())
            line_count += 1
            word_count += sentence_word_count
        else:
            break


    return ' '.join(trimmed_lines)


def generate_story_from_images(images, story_length, character, setting, tone, language):
    try:
        if isinstance(images, Image.Image):
            images = [images]

        images = [Image.fromarray(image) if not isinstance(image, Image.Image) else image for image in images]
        combined_captions = get_captions(images)

        if not character.strip():
            character = random.choice(default_characters)  # Random character
        if not setting.strip():
            setting = generate_relevant_setting(combined_captions)

        # Set the maximum tokens and lines based on story length
        if story_length == "Short":
            max_new_tokens = 50
            max_lines = 5
        elif story_length == "Medium":
            max_new_tokens = 100
            max_lines = 15
        else:  # Long
            max_new_tokens = 300
            max_lines = 90

        caption_in_story = integrate_caption_into_story(combined_captions, character, setting)

        story_prompt = (
            f"Once upon a time, in {setting}, there was a kind and brave character named {character}. "
            f"{caption_in_story} They had many adventures filled with fun and wonder."
        ) if tone == "Kids Story" else (
            f"In {setting}, a character named {character} faced challenges and deep emotions. "
            f"{caption_in_story} Their journey was filled with tension, suspense, and moments of heartfelt struggle."
        )

        # Check length and truncate if necessary
        if len(story_prompt) > 1024:  # Limit input length to prevent exceeding model limits
            story_prompt = story_prompt[:1024]

        # Generate the story
        story = story_generator(
            story_prompt,
            max_new_tokens=max_new_tokens,
            truncation=True,
            pad_token_id=story_generator.tokenizer.eos_token_id,
            num_return_sequences=1
        )
        generated_story = story[0]['generated_text']
        trimmed_story = trim_story(generated_story, max_lines)

        if language == "Arabic":
            trimmed_story = translator(trimmed_story)[0]['translation_text']

        return combined_captions, trimmed_story

    except Exception as e:
        return str(e), "Error generating story."


def text_to_speech(story_text, language):
    lang = 'ar' if language == "Arabic" else 'en'
    tts = gTTS(text=story_text, lang=lang)
    audio_file = "story.mp3"
    tts.save(audio_file)
    return audio_file


# Create a Gradio interface
with gr.Blocks() as interface:
    with gr.Row():
        image_input = gr.Image(type="pil", label="Upload Images")

    character_setting_language = gr.Row()
    character_input = gr.Textbox(label="Character Name (Optional)",
                                 placeholder="Enter character name...")
    setting_input = gr.Textbox(label="Setting (Optional)", placeholder="Enter story setting...")
    story_length = gr.Radio(
        choices=["Short", "Medium", "Long"],
        label="Select Story Length",
        value="Medium"  # Default value
    )

    language = gr.Radio(
        choices=["English", "Arabic"],
        label="Select Story Language",
        value="English"  # Default value
    )

    tone = gr.Radio(
        choices=["Kids Story", "Drama"],
        label="Select Story Style/Tone",
        value="Kids Story"  # Default value
    )

    image_descriptions = gr.Textbox(label="Image Descriptions", interactive=False)
    generated_story = gr.Textbox(label="Generated Story", interactive=False)

    submit_button = gr.Button("Generate Story")
    listen_button = gr.Button("Listen to Story")

    submit_button.click(
        fn=generate_story_from_images,
        inputs=[image_input, story_length, character_input, setting_input, tone, language],
        outputs=[image_descriptions, generated_story]
    )

    listen_button.click(
        fn=text_to_speech,
        inputs=[generated_story, language],
        outputs=gr.Audio(label="Story Audio", type="filepath")  # Output audio file
    )

# Launch the app
if __name__ == "__main__":
    interface.launch()
# Out:
# C:\Users\Yasser\iCloudDrive\Documents\Misc\Programming Projects\Tuwaiq DS and ML Bootcamp\Story Generation From photo\venv\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# Examples:
#
# 1- After giving a picture of a banana with a white background, the model generated the following story:
#     - Image Descriptions: A close-up of a banana on a white background.
#     - Generated Story: Once upon a time, in a mysterious place, there was a kind and brave character named Rania. Rania was surrounded by A banana on a white background during their adventure. They had many adventures filled with fun and wonder. Now she had to face them all and must become one of the greatest of all time. Is there anyone amongst us that has found the way beyond that, a hero that is truly beyond the pale?
#
# 2- After giving a picture of a snowy mountain with a Cabin ontop, the model generated the following story:
#     - Image Descriptions: a snowy scene with a log cabin and a snowy mountain
#     - Generated Story: Once upon a time, in a snowy mountain village, there was a kind and brave character named Noura. In a cozy log cabin on a snowy mountain, there lived a brave character named Noura. They had many adventures filled with fun and wonder.One day, Noura came to a young and handsome young man, to visit his mother. Noura was the first young man that didn't have a face. His mother made sure that he was told that in her village there was nothing
